# %%
import pandas as pd
df = pd.read_csv("data/processed/matches_clean.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5235 entries, 0 to 5234
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   team1          5235 non-null   object
#  1   team2          5235 non-null   object
#  2   venue          5235 non-null   object
#  3   toss_winner    5235 non-null   object
#  4   toss_decision  5235 non-null   object
#  5   winner         5235 non-null   object
#  6   date           5235 non-null   object
# dtypes: object(7)
# memory usage: 286.4+ KB

# %%
#df["winner"].value_counts().head(20)
df["toss_winner"].value_counts().head(20).mean()
# Out:
# np.float64(139.9)

# %%
df["winner"].value_counts().head(20)
# Out:
# winner
# India                   271
# England                 244
# Australia               237
# Pakistan                219
# New Zealand             202
# South Africa            191
# West Indies             160
# Sri Lanka               146
# United Arab Emirates    139
# Uganda                  132
# Ireland                 132
# Bangladesh              125
# Nepal                   122
# Zimbabwe                110
# Hong Kong               108
# Netherlands             108
# Malaysia                105
# Namibia                 102
# Thailand                 99
# Scotland                 94
# Name: count, dtype: int64

# %%
df["venue"].value_counts().head(20)
# Out:
# venue
# Al Amerat Cricket Ground Oman Cricket (Ministry Turf 1)        134
# Bayuemas Oval, Kuala Lumpur                                    121
# Dubai International Cricket Stadium                            110
# Gahanga International Cricket Stadium, Rwanda                   97
# Udayana Cricket Ground                                          95
# Terdthai Cricket Ground, Bangkok                                94
# Botswana Cricket Association Oval 1, Gaborone                   79
# Gahanga International Cricket Stadium. Rwanda                   73
# Harare Sports Club                                              72
# Marsa Sports Club                                               68
# West End Park International Cricket Stadium, Doha               58
# Tribhuvan University International Cricket Ground, Kirtipur     58
# Moara Vlasiei Cricket Ground, Ilfov County                      55
# Botswana Cricket Association Oval 2, Gaborone                   53
# Singapore National Cricket Ground                               50
# Bayer Uerdingen Cricket Ground                                  49
# Sano International Cricket Ground                               49
# Entebbe Cricket Oval                                            47
# Al Amerat Cricket Ground Oman Cricket (Ministry Turf 2)         47
# Mission Road Ground, Mong Kok, Hong Kong                        44
# Name: count, dtype: int64

# %%
df["date"] = pd.to_datetime(df["date"])
df["year"] = df["date"].dt.year
df["year"].value_counts().sort_index()
# Out:
# year
# 2005      3
# 2006      7
# 2007     35
# 2008     14
# 2009     51
# 2010     58
# 2011     22
# 2012     98
# 2013     58
# 2014     98
# 2015     62
# 2016    116
# 2017     63
# 2018    180
# 2019    335
# 2020    114
# 2021    381
# 2022    630
# 2023    587
# 2024    939
# 2025    913
# 2026    471
# Name: count, dtype: int64
